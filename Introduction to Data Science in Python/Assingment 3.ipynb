# %% [markdown]
# # Assignment 3 - More Pandas

# %% [markdown]
# This assignment requires more individual learning then the last one did - you are encouraged to check out the pandas documentation to find functions or methods you might not have used yet, or ask questions on stack overflow, and tag them as pandas and python related. And of course, the disscusion forums open for interaction with your peers and the course staff

# %% [markdown]
# ### Question 1 (20%)

# %% [markdown]
# Load the energy data from the file `Energy Indicators.xls`, which is a list of indicators of [energy supply and renewable electricity production](Energy%20Indicators.xls) from the [United Nations](http://unstats.un.org/unsd/environment/excel_file_tables/2013/Energy%20Indicators.xls) for the year 2013, and should be put into a DataFrame with the variable name of **energy**.
#
# Keep in mind that this is an Excel file, and not a comma separated values file. Also, make sure to exclude the footer and header information from the datafile. The first two columns are unneccessary, so you should get rid of them, and you should change the column labels so that the columns are:
#
# `['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']`
#
# Convert `Energy Supply` to gigajoules (there are 1,000,000 gigajoules in a petajoule). For all countries which have missing data (e.g. data with "...") make sure this is reflected as `np.NaN` values.
#
# Rename the following list of countries (for use in later questions):
#
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```
#
# There are also several countries with numbers and/or parenthesis in their name. Be sure to remove these,
#
# e.g.
#
# `'Bolivia (Plurinational State of)'` should be `'Bolivia'`,
#
# `'Switzerland17'` should be `'Switzerland'`.
#
# <br>
#
# Next, load the GDP data from the file `world_bank.csv`, which is a csv containing countries' GDP from 1960 to 2015 from [World Bank](http://data.worldbank.org/indicator/NY.GDP.MKTP.CD). Call this DataFrame **GDP**.
#
# Make sure to skip the header, and rename the following list of countries:
#
# ```"Korea, Rep.": "South Korea",
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```
#
# <br>
#
# Finally, load the [Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology](http://www.scimagojr.com/countryrank.php?category=2102) from the file `scimagojr-3.xlsx`, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame **ScimEn**.
#
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations',
#        'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
#
# *This function should return a DataFrame with 20 columns and 15 entries.*

# %%
import pandas as pd
import numpy as np

# %%
def answer_one():
    energy = pd.DataFrame(pd.read_excel("Energy Indicators.xls", skiprows = 17, skipfooter = 38))
    energy = energy[['Unnamed: 1', 'Petajoules', 'Gigajoules','%']]
    #energy.rename(columns={'Unnamed: 1':'Country', 'Petajoules':'Energy Supply', 'Gigajoules':'Energy Supply per Capita','%': '%Renewable'}, inplace = True)
    energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '%Renewable']
    energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']] = energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']].replace('...', np.NaN).apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*1000000  
    energy['Country'] = energy['Country'].replace({'Republic of Korea':'South Korea', 'United States of America':'United States', 'United Kingdom of Great Britain and Northern Ireland':'United Kingdom', 'China, Hong Kong Special Administrative Region':'Hong Kong', 'Bolivia (Plurinational State of)':'Bolivia', 'Switzerland17':'Switzerland', 'Venezuela (Bolivarian Republic of)':'Venezuela', 'Sint Maarten (Dutch part)':'Sint Maarten', 'Micronesia (Federated States of)':'Micronesia', 'Iran (Islamic Republic of)':'Iran', 'Falkland Islands (Malvinas)':'Falkland Islands'})

    GDP = pd.DataFrame(pd.read_csv("world_bank.csv", skiprows = 4))
    GDP[['Country Name']] = GDP[['Country Name']].replace({'Korea, Rep.':'South Korea', 'Iran, Islamic Rep.':'Iran','Hong Kong SAR, China':'Hong Kong'})
    rc = ['Country Name', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    GDP = GDP[rc]

    ScimEn = pd.DataFrame(pd.read_excel("scimagojr-3.xlsx", skipfooter = 176))
    #ScimEn_m = ScimEn[:15]

    fu = pd.merge(ScimEn, energy, how = 'left', left_on = 'Country', right_on = 'Country')
    FinalDF = pd.merge(fu, GDP, how = 'left', left_on = 'Country', right_on = 'Country Name')
    FinalDF = FinalDF[['Rank', 'Country', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '%Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']].set_index('Country')
    return FinalDF

answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %% [markdown]
# ### Question 2(6.6%)

# %% [markdown]
# The previous question joined three datasets then reduced this to just top 15 entries. When you join the datasets, but before you reduced this top 15 items, how many entries did you lose?
#
# *This function should return a single number.*

# %%
# %%HTML
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>
# Out:
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>

# %%
energy = pd.DataFrame(pd.read_excel("Energy Indicators.xls", skiprows = 17, skipfooter = 38))
energy = energy[['Unnamed: 1', 'Petajoules', 'Gigajoules','%']]
#energy.rename(columns={'Unnamed: 1':'Country', 'Petajoules':'Energy Supply', 'Gigajoules':'Energy Supply per Capita','%': '%Renewable'}, inplace = True)
energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '%Renewable']
energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']] = energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']].replace('...', np.NaN).apply(pd.to_numeric)
energy['Energy Supply'] = energy['Energy Supply']*1000000  
energy['Country'] = energy['Country'].replace({'Republic of Korea':'South Korea', 'United States of America':'United States', 'United Kingdom of Great Britain and Northern Ireland':'United Kingdom', 'China, Hong Kong Special Administrative Region':'Hong Kong', 'Bolivia (Plurinational State of)':'Bolivia', 'Switzerland17':'Switzerland', 'Venezuela (Bolivarian Republic of)':'Venezuela', 'Sint Maarten (Dutch part)':'Sint Maarten', 'Micronesia (Federated States of)':'Micronesia', 'Iran (Islamic Republic of)':'Iran', 'Falkland Islands (Malvinas)':'Falkland Islands'})

GDP = pd.DataFrame(pd.read_csv("world_bank.csv", skiprows = 4))
GDP[['Country Name']] = GDP[['Country Name']].replace({'Korea, Rep.':'South Korea', 'Iran, Islamic Rep.':'Iran','Hong Kong SAR, China':'Hong Kong'})
rc = ['Country Name', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
GDP = GDP[rc]

ScimEn = pd.DataFrame(pd.read_excel("scimagojr-3.xlsx", skipfooter = 176))
#ScimEn_m = ScimEn[:15]

# %%
def answer_two():
    fu2 = pd.merge(ScimEn, energy, how='outer', left_on = 'Country', right_on = 'Country')
    FinalDF2 = pd.merge(fu2, GDP, how='outer', left_on = 'Country', right_on = 'Country Name')
    return print(len(FinalDF2)-len(fu2))

answer_two()
# Out:
# 78

# %% [markdown]
# ### Question 3 (6.6%)

# %% [markdown]
# What is the average GDP over the last 10 years for each country? (exclude missing valuea from this calculation.)
#
# *This function should return a Series named avgGDP with 15 countries and their average GDP sorted in descending.*

# %%
energy = pd.DataFrame(pd.read_excel("Energy Indicators.xls", skiprows = 17, skipfooter = 38))
energy = energy[['Unnamed: 1', 'Petajoules', 'Gigajoules','%']]
#energy.rename(columns={'Unnamed: 1':'Country', 'Petajoules':'Energy Supply', 'Gigajoules':'Energy Supply per Capita','%': '%Renewable'}, inplace = True)
energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '%Renewable']
energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']] = energy[['Energy Supply', 'Energy Supply per Capita', '%Renewable']].replace('...', np.NaN).apply(pd.to_numeric)
energy['Energy Supply'] = energy['Energy Supply']*1000000  
energy['Country'] = energy['Country'].replace({'Republic of Korea':'South Korea', 'United States of America':'United States', 'United Kingdom of Great Britain and Northern Ireland':'United Kingdom', 'China, Hong Kong Special Administrative Region':'Hong Kong', 'Bolivia (Plurinational State of)':'Bolivia', 'Switzerland17':'Switzerland', 'Venezuela (Bolivarian Republic of)':'Venezuela', 'Sint Maarten (Dutch part)':'Sint Maarten', 'Micronesia (Federated States of)':'Micronesia', 'Iran (Islamic Republic of)':'Iran', 'Falkland Islands (Malvinas)':'Falkland Islands'})

GDP = pd.DataFrame(pd.read_csv("world_bank.csv", skiprows = 4))
GDP[['Country Name']] = GDP[['Country Name']].replace({'Korea, Rep.':'South Korea', 'Iran, Islamic Rep.':'Iran','Hong Kong SAR, China':'Hong Kong'})
rc = ['Country Name', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
GDP = GDP[rc]

ScimEn = pd.DataFrame(pd.read_excel("scimagojr-3.xlsx", skipfooter = 176))
#ScimEn_m = ScimEn[:15]
fu = pd.merge(ScimEn, energy, how = 'left', left_on = 'Country', right_on = 'Country')
FinalDF = pd.merge(fu, GDP, how = 'left', left_on = 'Country', right_on = 'Country Name')
FinalDF = FinalDF[['Rank', 'Country', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '%Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']].set_index('Country')

# %%
def answer_three():
    GDPcolumns = FinalDF[['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
    avgGDP = GDPcolumns.mean(axis=1).sort_values(ascending = False)
    return avgGDP

answer_three()
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %% [markdown]
# ### Question 4 (6.6%)

# %% [markdown]
# By how much had the GDP changed over the 10 year span for the country with the 6th largest average GDP?
#
# *This function should return a single number*

# %%
def answer_four():
    GDPcolumns = FinalDF[['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
    avgGDP = GDPcolumns.mean(axis=1).sort_values(ascending = False)
    sixth = GDPcolumns.loc[avgGDP.index[5]]
    diff = sixth['2015'] - sixth['2006']
    return diff

answer_four()
# Out:
# 246702696075.3999

# %% [markdown]
# ### Question 5 (6.6%)

# %% [markdown]
# What is the mean `Energy Supply per Capita`?
#
# *This fuction should return a sigle number*

# %%
def answer_five():
    ESPC = ['Energy Supply per Capita']
    avgESPC = FinalDF[ESPC].mean()
    return avgESPC

answer_five()
# Out:
# Energy Supply per Capita    157.6
# dtype: float64

# %% [markdown]
# ### Question 6 (6.6%)

# %% [markdown]
# What country has de maximun % Renewable and what is the percentage?
#
# *This fuction should return a tuple with the name of the country and the percentage.*

# %%
def answer_six():
    maxen = np.max(FinalDF['%Renewable'])
    idx = FinalDF[FinalDF['%Renewable'] == maxen].index[0]
    ans = (idx, maxen)
    return ans

# %%
answer_six()
# Out:
# ('Brazil', 69.64803)

# %% [markdown]
# ### Question 7 (6.6%)

# %% [markdown]
# Create a new column that is the ratio of Self-Citations to Total Citations. Whats is the maximun value for this this new column, and what country has the highest ratio?
# *This function should return a tuple with the name of the country and the ratio*
#
# `Ratio: is the quntitive relation between two amounts, showing the number of times one value contains or is contained within the other`

# %%
def answer_seven():
    FinalDF['Ratio'] = FinalDF['Self-citations']/FinalDF['Citations']
    maxrat = np.max(FinalDF['Ratio'])
    idxrat = FinalDF[FinalDF['Ratio'] == maxrat].index[0]
    return (idxrat,str(maxrat*100)+ ' %')

answer_seven()
# Out:
# ('China', '68.93126179389422 %')

# %% [markdown]
# ### Question 8 (6.6%)

# %% [markdown]
# Create a column that estimates the population using Energy Supply and Energy Supply per Capita. What is the third most populous country according to this estimate?
#
# *This function should return a single string value.*  `per Capita, means 'per each person`

# %%
def answer_eight():
    FinalDF['population'] = FinalDF['Energy Supply']/FinalDF['Energy Supply per Capita']
    thirdp = FinalDF['population'].nlargest(3)
    third = thirdp.iloc[2]
    namethird = thirdp[thirdp == third].index[0]
    return namethird

answer_eight()
# Out:
# 'United States'

# %% [markdown]
# ### Question 9 (6.6 %)

# %% [markdown]
# Create a column that estimates the number of citable documents per person. What is the correlation between the number of citable documents per capita and the energy supply per capita?
# use the `.corr() method, (Pearson's Correlation)`
#
# *This function should return a sigle number*
#
# (Optional: Use the built-in function plot9() to visualize the relationship between Energy Supply per Capita vs Citable docs per Capita)

# %%
def answer_nine():
    FinalDF['Citable per Capita'] = FinalDF['Citable documents']/FinalDF['population']
    corr = FinalDF['Citable per Capita'].corr(FinalDF['Energy Supply per Capita'])
    return corr

answer_nine()
# Out:
# 0.7940010435442942

# %%
def plot9():
    import matplotlib as plt
    # %matplotlib inline
    
    FinalDF['population'] = FinalDF['Energy Supply'] / FinalDF['Energy Supply per Capita']
    FinalDF['Citable per Capita'] = FinalDF['Citable documents'] / FinalDF['population']
    FinalDF.plot(x='Citable per Capita', y='Energy Supply per Capita', kind='scatter', xlim = [0, 0.0006])

# %%
plot9()

# %% [markdown]
# ### Question 10 (6.6%)

# %% [markdown]
# Create a new column with a 1 if the country's % Renewable value is at or above the median  for all countries in the top 15, and a 0 if the country's % Renewable value is belor the median.
#
# *This function should return a series named HighRenew whose index is the country name sorted in ascending order of rank.*

# %%
def answer_ten():
    median = FinalDF['%Renewable'].median() 
    FinalDF['HighRenew'] = [1 if result >= median else 0 for result in FinalDF['%Renewable']]
    return FinalDF['HighRenew']

answer_ten()
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %% [markdown]
# ### Question 11 (6.6%)

# %% [markdown]
# Use the following dictionary to group the Countries by Continent, then create a dataframe that displays the sample size (the number of countries in each continent bin), and teh sum, mean, and std deviation for the estimates population of each country.
#
# ```python
# ContinentDict = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}             ```
#
# This fuction should return a DataFrame sith index named `Continent['Asia','Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`

# %%
def df():
    return FinalDF
df()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
def answer_eleven():
    ContinentDict = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    ContinentDict = pd.Series(ContinentDict).reset_index()
    ContinentDict.columns = ['Country', 'Continent']
    cont = pd.DataFrame(ContinentDict)
    FinalDF = df()
    FinalDF = pd.merge(FinalDF, cont, how='inner', left_on = 'Country', right_on = 'Country')
    FinalDF = FinalDF.reset_index()
    operations = FinalDF.set_index('Continent').groupby(level = 0)['population'].agg({'size':np.size, 'sum':np.sum, 'mean':np.mean, 'std':np.std})
    cont_df = operations[['size', 'sum', 'mean', 'std' ]]
    return cont_df

answer_eleven()
# Out:
# /home/mariuki/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#                size           sum          mean           std
# Continent
# Asia            5.0  2.898666e+09  5.797333e+08  6.790979e+08
# Australia       1.0  2.331602e+07  2.331602e+07           NaN
# Europe          6.0  4.579297e+08  7.632161e+07  3.464767e+07
# North America   2.0  3.528552e+08  1.764276e+08  1.996696e+08
# South America   1.0  2.059153e+08  2.059153e+08           NaN

# %% [markdown]
# ### Question 12 (6.6%)

# %% [markdown]
# Cut %Renewable into 5 bins. Group Top15 by the Continent, as well as these new %Renewable bins. How many countries are in each of these groups?

# %% [markdown]
# *This function should return a Series with a Multindex of Continent, then the bins for %Renewable. Do not include groups with no countries.*

# %%
def answer_twelve():
    ContinentDict = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    ContinentDict = pd.Series(ContinentDict).reset_index()
    ContinentDict.columns = ['Country', 'Continent']
    cont = pd.DataFrame(ContinentDict)
    FinalDF = df()
    FinalDF = pd.merge(FinalDF, cont, how='inner', left_on = 'Country', right_on = 'Country')
    FinalDF['Bins']=pd.cut(FinalDF['%Renewable'],5)
    Groups = pd.Series(FinalDF.groupby(['Continent','Bins']).size())
    return Groups

answer_twelve()
# Out:
# Continent      Bins
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
# Australia      (2.212, 15.753]     1
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
# North America  (2.212, 15.753]     1
#                (56.174, 69.648]    1
# South America  (56.174, 69.648]    1
# dtype: int64

# %% [markdown]
# ### Question 13 (6.6 %)

# %% [markdown]
# Convert the Population Estimate series to a string with thousands seperator (using commas). Do not refound the results.
#
# eg 317615384.61538464 ->317,615,384.61538464
#
# *This function should return a series PopEst whose index is the country name and whose values are the population estimate string*

# %%
def answer_thirteen():
    import pandas as pd
    import numpy as np
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    
    FinalDF = df()
    mkls = list(FinalDF['population']) 
    FinalDF['population'] = (FinalDF['population']).apply(lambda comma: "{:,}".format(comma), mkls)
    ans = pd.Series(FinalDF['population'])
    
    
    return ans
answer_thirteen()
# Out:
# Country
# China                 1,367,645,161.2903225
# United States          317,615,384.61538464
# Japan                  127,409,395.97315437
# United Kingdom         63,870,967.741935484
# Russian Federation            143,500,000.0
# Canada                  35,239,864.86486486
# Germany                 80,369,696.96969697
# India                 1,276,730,769.2307692
# France                  63,837,349.39759036
# South Korea            49,805,429.864253394
# Italy                  59,908,256.880733944
# Spain                    46,443,396.2264151
# Iran                    77,075,630.25210084
# Australia              23,316,017.316017315
# Brazil                 205,915,254.23728815
# Name: population, dtype: object

# %% [markdown]
# ### Optional

# %% [markdown]
# Use the built option plot_optional() to see a example visisalization.

# %%
def plot_optional():
    import matplotlib as plt
    # %matplotlib inline
    FinalDF = answer_one()
    ax = FinalDF.plot(x='Rank', y='%Renewable', kind='scatter', 
                    c=['#e41a1c','#377eb8','#e41a1c','#4daf4a','#4daf4a','#377eb8','#4daf4a','#e41a1c',
                       '#4daf4a','#e41a1c','#4daf4a','#4daf4a','#e41a1c','#dede00','#ff7f00'], 
                    xticks=range(1,16), s=6*FinalDF['2014']/10**10, alpha=.75, figsize=[16,6]);

    for i, txt in enumerate(FinalDF.index):
        ax.annotate(txt, [FinalDF['Rank'][i], FinalDF['%Renewable'][i]], ha='center')

    print("This is an example of a visualization that can be created to help understand the data. \
This is a bubble chart showing % Renewable vs. Rank. The size of the bubble corresponds to the countries' \
2014 GDP, and the color corresponds to the continent.")

# %%
plot_optional()
# Out:
# This is an example of a visualization that can be created to help understand the data. This is a bubble chart showing % Renewable vs. Rank. The size of the bubble corresponds to the countries' 2014 GDP, and the color corresponds to the continent.
